# %% [markdown]
# ## Download a GeoTIFF tile from OpenTopography and display it.

# %%
"""
Download a GeoTIFF tile from OpenTopography and display it.

Dependencies
------------
pip install requests rasterio matplotlib
"""
from __future__ import annotations

import io
import sys
import zipfile
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import rasterio
import requests

from pyproj import Transformer
from dotenv import load_dotenv
import os
load_dotenv()

from typing import Tuple
import base64
from openai import OpenAI
import os

def raster_to_png_data_url(
    tif_path: Path, size: Tuple[int, int] = (512, 512)
) -> str:
    """
    Down-sample the first band of the GeoTIFF, scale to 8-bit, and
    return a data-URL (PNG, base-64) suitable for the OpenAI vision API.
    """
    with rasterio.open(tif_path) as src:
        data = src.read(1, masked=True).astype(np.float32)

    # Simple min-max stretch → 0-255
    z_min, z_max = np.nanmin(data), np.nanmax(data)
    arr = np.clip((data - z_min) / (z_max - z_min + 1e-9) * 255, 0, 255).astype(
        np.uint8
    )

    # Resize to something manageable for the API
    fig = plt.figure(frameon=False)
    fig.set_size_inches(*[s / 100 for s in size])
    ax = plt.Axes(fig, [0.0, 0.0, 1.0, 1.0])
    ax.set_axis_off()
    fig.add_axes(ax)
    ax.imshow(arr, cmap="gray", origin="upper")
    buf = io.BytesIO()
    fig.savefig(buf, format="png", dpi=100)
    plt.close(fig)

    png_base64 = base64.b64encode(buf.getvalue()).decode("ascii")
    return f"data:image/png;base64,{png_base64}"

def png_to_data_url(png_path: Path)-> str:
    """
    Convert a PNG file to a data-URL (base-64) suitable for the OpenAI vision API.
    """
    with open(png_path, "rb") as f:
        png_base64 = base64.b64encode(f.read()).decode("ascii")
    return f"data:image/png;base64,{png_base64}" 

def analyse_with_openai(
    image_data_urls: list[str],
    prompt: str = "Describe the major terrain / geomorphological features visible in these images in detail and look carefully for any archeologically interesting anomalies present. These are taken from sites in the Amazon, in and around Brazil.",
    model: str = "o4-mini",
    max_tokens: int = 400,
) -> str:
    """
    Send an image + prompt to GPT-4o’s vision endpoint and return the text.
    """
    client = OpenAI()  # picks up OPENAI_API_KEY from env
    print("→ Contacting OpenAI …")
    completion = client.chat.completions.create(
        model=model,
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": prompt},
                    *[{"type": "image_url", "image_url": {"url": url, "detail": "high"}} for url in image_data_urls],
                ],
            }
        ],
        # max_tokens=max_tokens,
    )
    return completion.choices[0].message.content.strip()


def convert_utm_to_wgs84(utm_x, utm_y):
    # Define the transformer: from UTM zone 19S (EPSG:32719) to WGS 84 (EPSG:4326)
    transformer = Transformer.from_crs("EPSG:32719", "EPSG:4326", always_xy=True)

    # Convert to latitude and longitude
    lon, lat = transformer.transform(utm_x, utm_y)

    return lon, lat


def fetch_raster_tile_from_opentopography(
    api_key: str,
    dataset: str,
    north: float,
    south: float,
    east: float,
    west: float,
    dest: Path = Path("tile.tif"),
    source: str = "globaldem"
) -> Path:
    """
    Download a GeoTIFF tile from OpenTopography’s Point-Cloud API.

    Returns
    -------
    Path
        Path to the downloaded `.tif` file (possibly extracted from a ZIP).
    """
    outputFormat = "GTiff"
    ds_key = ""
    if source == "usgsdem":
        ds_key = "datasetName"
    elif source == "globaldem":
        ds_key = "demtype"
    else:
        raise ValueError(f"Invalid source: {source}")
    url = f"https://portal.opentopography.org/API/{source}?{ds_key}={dataset}&north={str(north)}&south={str(south)}&east={str(east)}&west={str(west)}&outputFormat={outputFormat}&API_Key={api_key}"

    # print("Requesting data from ", url)

    r = requests.get(url,  timeout=300)
    if (len(r.content) < 200):
        print(r.content)
    r.raise_for_status()

    # The service may send back either a bare .tif or a ZIP archive.
    content_type = r.headers.get("content-type", "")
    if "zip" in content_type or r.content[:2] == b"PK":
        with zipfile.ZipFile(io.BytesIO(r.content)) as zf:
            tif_name = next(n for n in zf.namelist() if n.lower().endswith(".tif"))
            zf.extract(tif_name, dest.parent)
            dest = dest.parent / tif_name
    else:
        dest.write_bytes(r.content)

    print(f"Saved raster tile to {dest.resolve()}")
    return dest


def display_raster(path: Path) -> None:
    """Render the GeoTIFF elevation raster with matplotlib."""
    with rasterio.open(path) as src:
        data = src.read(1, masked=True)  # first band
        bounds = src.bounds

    fig, ax = plt.subplots(figsize=(20, 20))
    extent = [bounds.left, bounds.right, bounds.bottom, bounds.top]
    im = ax.imshow(
        data, cmap="terrain", extent=extent, origin="upper"
    )
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    ax.set_title(f"{path.name}  –  Elevation (m)")
    cbar = fig.colorbar(im, ax=ax, shrink=0.7)
    cbar.set_label("Elevation (m)")
    plt.tight_layout()
    plt.show()

api_key = os.environ.get("OPENTOPOGRAPHY_API_KEY")
all_files = list(set(list(map(lambda x: x.split('.')[0], filter(lambda x: x.endswith('.png'), os.listdir('stitched_images'))))))
for filename in all_files:
    print(f"Processing {filename}...")
    json_file = f"stitched_images/{filename}_location.json"
    png_file = f"stitched_images/{filename}.png"

    with open(json_file, "r") as f:
        bounds_utm = eval(f.read())["bounds_projected"]
    bounds = {
        "north": convert_utm_to_wgs84(bounds_utm["max_x"], bounds_utm["max_y"])[1],
        "south": convert_utm_to_wgs84(bounds_utm["min_x"], bounds_utm["min_y"])[1],
        "east": convert_utm_to_wgs84(bounds_utm["max_x"], bounds_utm["max_y"])[0],
        "west": convert_utm_to_wgs84(bounds_utm["min_x"], bounds_utm["min_y"])[0]
    }
    north = bounds["north"]+0.05
    south = bounds["south"]-0.05
    east = bounds["east"]+0.05
    west = bounds["west"]-0.05
    dataset = "SRTMGL1"

    out_path_1 = fetch_raster_tile_from_opentopography(api_key, dataset, north, south, east, west, source="globaldem")
    data_url_1 = raster_to_png_data_url(out_path_1)
    data_url_2 = png_to_data_url(png_file)

    analysis = analyse_with_openai([data_url_1, data_url_2])
    print(f"Analysis for {filename}:\n{analysis}\n")
# Out:
# Processing ANT_A01_2011_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for ANT_A01_2011_stitched:
# Here’s what I see in each of the two panels.  I have tried to call out the main land‐form elements first, then comment on anything that might strike one as “man‐made.”
#
# 1.  Panel One (512×512 DEM crop)
#    •  Dendritic Drainage Pattern
#       –  A classic tree‐like (dendritic) network of small side‐gullies feeding into a larger, primary valley.  The tributaries are very regularly spaced, with narrow V-shaped cross sections.
#       –  The main valley runs roughly from the upper right toward the lower left and collects all of the smaller branches.
#
#    •  Interfluves and Ridges
#       –  Between each of those small gullies sit narrow, sharp interfluves or ridges.  Their symmetry and regular spacing tell you the rock or soil here is fairly homogeneous—there are no big lithologic contrasts steering the streams into wider, flat‐bottomed valleys or amphitheaters.
#
#    •  Dissection of a Gently Rolling Plateau
#       –  The overall impression is of a low‐relief upland that has been cut into by shallow, incising streams.  Slopes appear moderate to steep on the sides of each gully but the ridge crests are broadly rounded.  This is exactly what you’d expect on the weathered Brazilian Shield or one of its satellite plateaus.
#
#    •  Archaeological “Anomalies”?
#       –  I do not see any systematically straight lines, right angles, perfect circles or patterns of mounds and ditches here.  Everything follows the natural branching of watercourses.  There are a handful of slightly deeper hollows along some of the interfluves, but they are irregular in shape and spacing and almost certainly erosional in origin (soil pipes, headward erosion) rather than pit houses, sunken plazas or agricultural terraces.
#
# 2.  Panel Two (768×1 229 grayscale)
#    •  Broad Plains Transitioning to Steeper Ground
#       –  On the left side of the frame you have an almost featureless, very low‐relief expanse (shown here as a darker uniform tone).  That suggests either a floodplain or a filled‐in upland surface with very subdued microtopography.
#       –  Toward the right the tone brightens and you begin to pick out faint, fine‐scaled lineations—these look much like the tiny channel‐networks in Panel One, but even less incised.  They too coalesce into a main trough or valley along the mid‐right edge.
#
#    •  Gentle Slopes to Slightly Incised Ridges
#       –  A subtle convex break‐in‐slope separates the left “flat” zone from the right “dissected” zone.  Such a transition is characteristic of a setting where a river once spread a sheet of sediment (left) and then later cut down into it (right).
#
#    •  Lack of Clear Geometric Forms
#       –  There are no regular rectangles or perfect circles that would shout “geoglyph.”  Nor do I see the parallel ridges and furrows that would mark large pre-Columbian raised‐field complexes (e.g. fields at Lake Cameroons).
#       –  All the lineations follow dendritic or sub‐dendritic paths; none form rectilinear grids.
#
#    •  Potential Subtle Hints (but low confidence)
#       –  If you look very carefully in the mid‐left zone you might persuade yourself there are a couple of very shallow, nearly straight line segments—just a few tens of meters long.  In Amazon research, those sometimes turn out to be minor footpaths, old drainage canals or abandoned ditches.  In this particular crop, however, they are at the limit of the DEM’s signal‐to‐noise, and I would not stake a case on them without ground truth.
#
# Summary
# Both scenes are dominated by natural, fluvially dissected uplands and adjacent floodplain (or filled‐in) surfaces.  The branching, V-shaped channels and sharp interfluves in Panel One are textbook examples of uniform‐substrate erosion.  The broad, featureless left side of Panel Two contrasts with its slightly dissected right side, marking a shift from a former overbank or eolian‐filled plain into active incision.
#
# There are no unmistakable archaeological earthworks—no true geometric enclosures, evenly spaced mound-and-ditch systems or orthogonal grid patterns.  If anything, there are a handful of very subtle, short, straight‐ish lineations in Panel Two that one could hypothesize as ancient canals or path remnants—but they lie right at the noise threshold of the data.  On balance, both panels look purely geomorphological rather than cultural.
#
# Processing DUC_A01_2012_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for DUC_A01_2012_stitched:
# Below is a systematic description of what you are seeing in these LiDAR‐style shaded‐relief views of Amazonian terrain, together with a brief note on whether any anthropogenic (archaeologically interesting) features jump out.
#
# 1. Overall Morphology
#    • Dendritic Drainage Network
#      – A classic tree-like (dendritic) pattern of small, branching channels feeding into ever-larger trunks.
#      – The channels are shallow (just a few meters deep) and closely spaced—typical of a uniformly erodible substrate, such as fine alluvium or weathered bedrock.
#    • Low‐relief Interfluves and Hillocks
#      – Between the incised channels lie broad, gently sloping interfluves (the “plateau” between streams) with elevations differing by only 5–15 m.
#      – Some slightly higher, rounded knolls rise a few meters above the surrounding plain—these could be erosional remnants or local depositional mounds.
#    • Meander Scars and Oxbows
#      – In a few places the linear channels curve around faint, crescentic depressions—the hallmark of abandoned meanders (“oxbow lakes”) now filled or partially filled with sediment.
#    • Subtle Terrace Steps
#      – Look closely and you may see one or two very low bench-like steps along the steeper valley walls—possible river-terrace remnants from past river levels.
#
# 2. Paleolandscape Indicators
#    • Old / Buried Channels
#      – The faintest linear depressions, a little broader and shallower than active streams, are likely relict channels or paleoriver courses cut and then filled in before the modern landscape stabilized.
#    • Uniform Texture
#      – Almost all the small ridges and troughs follow natural drainage; there is no obvious change in grain (texture) or orientation that would betray large-scale quarrying or excavations.
#
# 3. Archaeological Anomaly Checklist
#    • Geometric Earthworks
#      – No clear circles, squares, or rectilinear enclosures stand out. Amazonian geoglyphs often show very sharp, straight-edged ditches and berms; here the ridges and hollows are all smoothly curved and dendritic.
#    • Raised Fields or Causeways
#      – Occasionally one can see parallel linear ridges (1–2 m tall, tens of meters apart) if raised agricultural platforms are present. In these images, I do not detect any strongly parallel sets of ridges with consistent spacing.
#    • Mounded Structures
#      – A few of the knolls are slightly sharper-peaked than you’d expect from pure erosion. If these recur in a regular grid or are accompanied by surrounding ditches, they might be habitation mounds—however, their spacing and form here look random and more consistent with natural erosional remnants.
#    • Long, Straight Alignments
#      – Human‐made roads or causeways show up as narrow, very straight, linear features cutting right across drainage patterns. I see no lines of that character.
#
# 4. Interpretation
#    – The landscape is dominated by young, active fluvial processes on a low‐gradient plain.
#    – Relief is low: typically 5–15 m from valley bottoms up to the highest knolls.
#    – Drainage is dense and dendritic—there is no evidence of an underlying structural control (e.g. fault lineaments or bedrock fractures).
#    – All the small mounds and ridges conform to natural drainage geometry; nothing stands out as a clear‐cut earthwork.
#
# 5. Recommendations for Field Follow-Up
#    • Ground-truth the few sharper knolls—walk‐in GPS surveys or small test pits could confirm whether any hold cultural stratigraphy.
#    • Overlay soil maps or satellite multispectral data to see if the suspected mounds correspond to unusual surface soils (e.g. Amazonian “terra preta”).
#    • If very-high-resolution LiDAR is available, reprocess with a slightly steeper illumination angle—it sometimes makes straight or man-made lines “pop” against the organic curvilinear background.
#
# In short, what you’re seeing is textbook Amazonian lowland relief—dense dendritic streams and subtle interfluves—with no unambiguous signs of human‐made geometric earthworks or raised fields in these particular panels.
#
# Processing FN1_A01_2016_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for FN1_A01_2016_stitched:
# Here’s a breakdown of what you’re seeing in these two panels and where to look for anything that might be man-made beneath the natural terrain:
#
# 1. Overall setting (first panel, greyscale hillshade)
#    • Major drainage network in the upper third of the image
#      – A dendritic (tree-like) pattern of narrow, dark “veins.” Those are small headwater channels cutting into a resistant substrate, probably shallow lateritic caprock or bedrock outcrops.
#      – The channels fan out toward the image-top edge, indicating a catchment divide just off-frame.
#
#    • Broad, low-angle slopes in the middle third
#      – A fairly uniform mid-tone with only very gentle micro-relief. This is almost certainly the active floodplain of a large Amazon tributary—fine alluvial silt and clay with only subtle scours and small levees.
#      – The lack of strong tonal contrast means we’re looking at an area that rarely drops below a few meters of relief.
#
#    • Patchy depressions and small oxbow scars in the lower third
#      – A series of rounded, darker “pock-marks.” These correspond to abandoned meander loops (oxbows) that have been partially infilled.
#      – Some of the more circular depressions show slightly raised rims (pale halos around dark centers), which in many Amazon floodplains can mark the edges of ancient channels or even anthropogenic ponds.
#
# 2. Key geomorphic transitions
#    • From headwaters (rough, rocky interfluves) down to the fine‐grained floodplain you go through a break in slope reflected as a subtle tonal gradient in the centre of the image.
#    • That break marks the transition from an erosional domain (upper third) to a depositional one (middle & lower thirds).
#
# 3. Archaeological “anomalies” to watch for
#    a) Regularly spaced circular or rectangular mounds
#       – Look especially at the cluster ~25–30% up from the bottom, slightly right of center. I see faint ring-shaped rims about 50–80 m in diameter. On the ground these often turn out to be habitation mounds or earthworks.
#    b) Straight-line embankments or causeways
#       – In the second (binary) image you’ll notice white linear segments that are unnaturally straight and consistently spaced—especially in the mid-left quadrant. Those lines break the natural drainage orientation by 20–30°.
#       – Such linear features in Amazon LIDAR are almost always raised “roads” or canals cut by pre-Columbian societies.
#    c) Rectilinear enclosures
#       – A faint square or rectangular outline just above center in the binary overlay. The corners are all right angles and the sides run almost exactly north–south/east–west.
#       – In a natural setting you almost never get perfect 90° corners on a scale of hundreds of meters, so this strongly suggests buried walls or ditches.
#
# 4. How these observations tie together
#    • The headwater ridges supplied sand and clay to the floodplain below; ancient communities commonly built raised fields (camellones) right on that new sediment.
#    • The oval depressions are both natural oxbows and sometimes deliberately dug reservoirs. Where you see a raised rim around a dark pit, test-pitting on the ground often finds pottery shards in the upper fill.
#    • The overlay of straight causeways (seen as white lines) running off those mounds and enclosures is the tell-tale of pre-Hispanic land-use grids used to connect villages, fish-weirs, and fields.
#
# Take-home points:
# • Natural geomorphology transitions from rocky headwaters down to a fine floodplain with oxbow remnants.
# • The "anomalies" — circular mounds with raised rims, rectilinear outlines, and straight causeways — are classic signatures of Amazonian earthworks (raised fields, canals, roads, and village sites).
#
# Next steps would be targeted ground-truthing (walk-in GPS surveys, auger probes) at those ring-mound sites and along the long straight embankments to confirm their archaeological nature.
#
# Processing AND_A01_2013_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for AND_A01_2013_stitched:
# The two images you provided (the first a high‐resolution shaded‐relief or hillshade DEM, the second apparently a masked or clipped version of the same) show essentially the same piece of low‐relief Amazonian terrain.  Here’s what stands out:
#
# 1. Dendritic Drainage Network
#    • The most obvious feature is a classic dendritic (tree-like) pattern of small stream channels and gullies.  These first- and second-order tributaries branch at roughly 60–90° angles into a slightly larger “trunk” channel that bisects the image from upper left toward lower right.
#    • No large meanders or oxbow lakes are visible; the channels appear relatively straight to gently curving, incising a few meters into the interfluves.
#
# 2. Low-Relief Interfluves and Convex Hilltops
#    • Between all of those small channels are smooth, rounded interfluves (divide areas).  They form broad, gently convex hilltops only a few meters higher than the valley floors.
#    • The tonal range (light grays on crests, darker grays in hollows) suggests overall relief differences of perhaps 5–10 m from ridge to channel floor.
#
# 3. Valley Geometry and Soil/Hydrology Implications
#    • Cross-sections through the valleys look “V-shaped,” indicating active downcutting in relatively cohesive, lateritic or saprolitic soils rather than wide, open swamps.
#    • The uniformity of the drainage pattern and the angle of the tributaries imply a homogenous substrate—there is no abrupt lithologic change (e.g. a hard sandstone bench or resistant volcanic bed) forcing a trellis or rectangular drainage.
#
# 4. Absence of Large Fluvial Terraces or Floodplain Features
#    • There are no clearly delineated stepped terraces, broad floodplains, or bench levels that would indicate a history of fluctuating base level or major climatic shifts preserved at this scale.
#
# 5. Archaeological Anomaly Search
#    • At this resolution and in the absence of strong rectilinear, circular, or orthogonal outlines, there are no unambiguous anthropogenic earthworks (such as geometric “Amazonian geoglyphs,” roads, or raised rectangular fields) visible.
#    • Sometimes very subtle raised-field agriculture or slightly elevated “terra preta” platforms can show up as faint plateaus or grid-like bumps on a high-quality DEM; I do not see any regularly spaced ridges, right-angle intersections, or circular ditches indicative of pre-Columbian enclosures.
#    • The interfluves are smooth and naturally convex; the small ridges you see are simply the intervening stream divides and not man‐made causeways.
#
# 6. Interpretation
#    • Geomorphologically, this is a mature, low‐relief tropical landscape carved by shallow, youthful streams that have not yet developed large floodplains or terraces.
#    • Without sharper edges or straight-line alignments, nothing jumps out here as a human‐made feature. If you suspect buried earthworks, you would need either higher‐contrast LiDAR hillshades (to accentuate centimeter‐scale microrelief) or overlay of known archaeological site coordinates.
#
# Bottom line: the scene is dominated by a natural dendritic drainage dissection of a gently undulating upland. At the scale and grayscale ranges shown, I see no clear anthropogenic anomalies (geoglyphs, raised fields, enclosure ditches) – it appears to be an entirely natural fluvial‐geomorphic setting.
#
# Processing BON_A01_2018_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for BON_A01_2018_stitched:
# Below is a summary of the principal landforms I see in these mosaicked altitude/relief (likely LiDAR‐derived) frames, together with a note on subtly anomalous patterns that could merit on-the‐ground archaeological follow-up.
#
# 1. Broad Floodplain with Meander Scars
#    • The dominant setting is a low‐gradient floodplain.  You can see it in the gently undulating, very low-relief surface.
#    • Across most of the scene, vestigial paleo‐meander loops and cutoff channels appear as sinuous, slightly darker (lower) strips.  These are former river courses that have since been abandoned and infilled.
#
# 2. Low Levees and Natural Terraces
#    • Parallel, almost evenly spaced linear ridges (lighter tones, since they are a few decimeters higher) run roughly NW–SE.  Their spacing is typically on the order of 50–150 m.
#    • These are natural levees formed each time the river overbanked its banks and dumped coarser sediment; over many floods they build up faint north‐ and south-side ridges at roughly constant elevation.
#
# 3. Inter-Levee Swales
#    • Between the ridges you see gentle swales, 10–20 cm deeper, where finer silts and clays settled on the quieter floodplain.  These darker swales may hold water in the wet season and would have been attractive for cultivation or pond digging.
#
# 4. Minor Tributary Confluences
#    • Toward the NW quadrant, several small tributary channels drain into the main paleochannel.  Their dendritic branching is natural, but at very fine scale one or two of these appear unnaturally straight for lengths of 100–200 m.
#
# 5. Subtle Rectilinear and Circular Anomalies
#    • In the central‐southern part of the first image there is a near-perfect circular depression (roughly 80–120 m across).  Its rim is only 20–30 cm higher than its floor, but its outline is distinctly round compared to the meandering natural channels.
#    • A little northeast of that same circle, two straight embankments meet at nearly a right angle.  Each leg is about 150 m long, running N–S and E–W, and stands 0.3–0.5 m above the surrounding terrain.  Those orthogonal intersections are extremely unlikely to form by purely fluvial processes.
#    • On the second (larger mosaic) image there are faint, parallel strips about 10–15 m wide and spaced 30–40 m apart, running roughly NE–SW.  These could be the remains of raised agricultural beds or planted lines, now overgrown but still differing in elevation by a few decimeters.
#
# 6. Raised Mound Clusters
#    • Scattered around the mid-frame of the second image are small, circular mounds ~3–5 m diameter and 0.5–1 m high.  Some occur in loose groups of three to five in a rough ring.  These might be domestic or funerary mounds.
#
# Interpretation & Next Steps
# – The broad floodplain and levee/terrace sequence is entirely natural, carved by the ancient meandering Amazon tributaries.
# – However, the perfectly circular hollow and the orthogonal embankments are classical hallmarks of Amazonian geoglyphs (ring ditches and rectangular earthworks) that have been reported elsewhere in Brazil’s Acre and Rondônia states.
# – The linear, equally spaced “strips” and small clustered mounds likewise fit the pattern of pre-Columbian raised-field agriculture and small habitation sites.
#
# I would recommend targeted ground-truthing—walking transects with GPS and shallow probing—around:
#   • The circular depression in the first image’s south center.
#   • The right-angled embankment junction just to its northeast.
#   • Any of those straight‐line paleochannels that run unusually far without the smooth curvature of a natural stream.
#
# If confirmed by test pits or auger cores (to look for charcoal, pottery shards, or midden soils), these features could very well be Late Holocene geoglyphs and raised-field remains, adding to the growing evidence of complex riverine societies in the pre-Columbian Amazon.
#
# Processing FN2_A01_2018_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for FN2_A01_2018_stitched:
# Below is a feature‐by‐feature walk-through of what the four panels appear to show, first in terms of the large-scale landforms and drainage, and then in terms of the small but suspiciously regular anomalies that stand out against the otherwise “natural” Amazon floodplain.
#
# 1. Major geomorphological framework
#    • Dendritic drainage and paleochannels
#      – You can see a classic dendritic (tree-like) network of shallow valleys, with a single main stem (the darker sinuous trunk in the center of panels 1 and 3) and many smaller tributaries fanning off.
#      – In a couple of places those tributaries terminate in horseshoe-shaped “oxbow” depressions (old meander scars) rather than flowing continuously, telling you these are relict floodplain channels.
#
#    • Natural levees, back-swamps and terraces
#      – Immediately flanking the active channels are narrow, slightly elevated ridges (light‐tone linear strips) that would act as natural levees during floods.
#      – Beyond those levees the tone becomes darker and flatter, consistent with periodically inundated back‐swamps or depositional wetlands.
#      – Further upslope (toward the margins of each tile) you see broad, gently undulating surfaces in alternating light and dark tones—these are likely low river terraces or remnants of older floodplain surfaces.
#
#    • Micro-relief on the wider floodplain
#      – Interspersed amongst the darker back-swamp areas are patchy, very low mounds and depressions, giving a “bubbly” texture to the plain. Some of these are almost random, the result of root-throws, termite mounds or small oxbow lake fill.
#
# 2. Archaeologically interesting anomalies
#    Against that natural backdrop, a few features stand out because of their unusually straight lines, repeated spacing or near-perfect geometry:
#
#    A. Parallel linear embankments
#      – In the southeastern quadrant of panel #1 there is a set of two or three almost perfectly parallel ridges, each some 5–10 m wide, running roughly north–south for over a hundred meters. Natural levees tend to taper and shift; these maintain constant width and alignment, suggesting human-built causeways or raised agricultural beds.
#
#    B. Rectangular/orthogonal patterns
#      – In panel #4 (the wider 184 × 1 400 strip) toward its mid-height you can pick out a faint rectangular enclosure about 150 × 80 m in plan. Its embankments are just a few decimeters high (hence low contrast) but hold straight sides and consistent corner angles. This “box” cuts across the grain of natural drainage.
#
#    C. Circular/annular ditches
#      – In panel #3 (the very narrow 32 × 1 376 strip) at roughly 2/3 of its length there is a ring‐shaped feature ~80–120 m across, visible as a slightly darker moat encircling a lighter‐tone interior. Natural ponds in this region are rarely perfectly round; this suggests a small geoglyph or ceremonial enclosure.
#
#    D. Regular grid of low platforms
#      – If you look closely in the lower half of panel #1 you can see a loose grid—small, rectangular raised areas spaced about 30–40 m apart, each a few meters across. This pattern is too uniform to be chance termite activity and matches the footprint of known Amazonian “garden cities” or raised‐field systems.
#
# 3. Interpretation and next steps
#    • Taken together, these straight edges, right angles and repeated modules are classic hallmarks of earthworks. In this part of Brazil and adjacent Amazon states they have been ascribed to pre-Columbian polities that built:
#      – geometric enclosures (sometimes called “geoglyphs”),
#      – causeways connecting villages,
#      – raised agricultural terraces, and
#      – fish‐pond systems.
#
#    • Ground-truthing or high-resolution LIDAR would help confirm whether these are indeed human‐made embankments and ditches, or merely natural erosional artefacts that happen to look regular at this scale.
#
#    • A systematic survey (magnetometry, shallow augering) along the straight features and around the ring could quickly establish the presence of charcoal, artifacts or anthropic soil horizons.
#
# In sum, while the broad picture is one of typical Amazon floodplain relief—meandering creeks, levees, back-swamps—several linear embankments, orthogonal enclosures and ring-ditch features almost certainly merit archaeological follow-up.
#
# Processing ANA_A01_2018_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for ANA_A01_2018_stitched:
# Here’s a description of what I see in both panels, first from a purely geomorphic standpoint and then pointing out the places where you might want to go back and check on the ground for possible earth‐works or other cultural “anomalies.”
#
# 1.  Image #1 (single 512×512 tile)
#
#    – Overall pattern: a classic dendritic drainage network incised into what looks like a relatively homogeneous, lateritic or clayey plateau.
#    – Major channels: a “trunk” stream enters from the lower right corner and bifurcates as it climbs up toward the upper centre. Average tributary spacing is on the order of 50–100 m, with branching angles of roughly 30–45°. That uniformity is a hallmark of natural erosion in a single‐rock‐type setting.
#    – Terrace or scarp on the left: along the left edge there’s a distinctly brighter, nearly vertical band (20–30 m wide) that drops off rather abruptly into a deeper trough. That appears to be the edge of a slightly more resistant caprock or a remnant terrace bench.
#    – Micro‐benches: just to the right of that scarp, and again in two or three spots in the central 50 % of the image, you can make out very subtle, concentric “half‐bench” steps—these are only 1–3 m in relief but run more or less parallel to the main channel. In many Amazonian earthwork surveys those can coincide with the rims of buried mounds or low ring‐ditch layouts.
#    – Faint straight‐line “ridge”: look at about the 40 %–50 % mark from the bottom, running almost north–south for 150–200 m before “losing” itself in the natural branching pattern. It is only 0.5–1 m higher than the surrounding ground—far too subtle to be a natural fault. This is your best candidate here for an anthropogenic embankment or causeway.
#
# 2.  Image #2 (composite of multiple tiles)
#
#    – Very low overall relief: most of the scene changes by less than 5 m end‐to‐end, consistent with an abandoned floodplain or very mature pediplain.
#    – “Dark halos” or “tree-island” mounds: there are a handful of roughly circular/domed features (40–60 m diameter) shown in darker shading—I interpret those as elevated forest islands or truncated natural mounds. Across the Amazon these often mark old archaeological “mound” sites that escaped clearance and so stand out in the LiDAR DTM.
#    – Absence of large natural channels: unlike image #1, there are no clear trunk streams here, which again points to a very flat, ponded‐water setting. In many parts of the Central Amazon such settings were deliberately raised into garden‐fields by pre‐Columbian farmers.
#    – Subtle rectilinear hints: if you look especially in the lower centre of the mosaic you can just make out two nearly straight lines meeting at an angle of close to 90°—they’re only a metre or less above the surrounding plain, but they extend for 100–120 m each. Those lines are too straight and too uniform to be random depressions in a floodplain.
#    – Tile‐edge artifacts: be aware that the darker “blobs” in the upper left and the very dark zone in the lower left of the full‐scene are almost certainly just shadow‐ or processing‐artifacts from the way the LiDAR tiles were stitched. Don’t read too much into those.
#
# 3.  Archaeological “targets”
#
#    – In image #1 the single straight segment of slightly raised ground running N–S at mid-frame is your #1 pick. It cuts across the normal drainage pattern, is too uniform to be natural, and lies just downslope of a terrace scarp (a good place to back‐fill a ditch).
#    – In image #2 the junction of the two faint right‐angle embankments in the lower centre is worth a helicopter‐overfly or better yet a ground‐penetrating radar transect. Paired with the nearby domed “mound” islands, that quadrant of the plain has a high chance of preserving buried postholes or small house-platforms.
#    – None of the other channels or circular features here deviate from what you’d expect in natural Amazonian fluvial or colluvial settings (i.e. dendritic streams, forest islands). So focus your field checks on the subtle linear/rectilinear scars.
#
# In short, both scenes are dominated by natural, low‐relief, dendritic/fluvial terrain, but each contains faint linear ridges and right-angled intersections—very often the signature of ancient enclosures, causeways, or raised fields in this part of the Amazon. I’d begin with targeted ground truthing (ground‐penetrating radar or auger probes) along those straight segments and at the corners of the faint rectangles.
#
# Processing ANTL5800C8972_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for ANTL5800C8972_stitched:
# Below is a summary of what the two panels show (the second being essentially blank/featureless) and what, if anything, in the first panel could be archaeological rather than purely natural.
#
# 1.  Panel A (upper-left):
#    •  Hill-shade / shaded-relief view (or high-pass grayscale DEM) of a low-relief, heavily dissected terrain.
#    •  The dominant pattern is a classic dendritic drainage network:
#       –  Numerous small, V-shaped gullies converge into larger ephemeral channels.
#       –  Ridges between the gullies are smooth, convex-up in cross section, and appear to be underlain by relatively homogeneous, easily eroded sediments or weathered bedrock.
#       –  The valley-to-ridge relief is quite low (tens of meters at most), consistent with mature erosion in a humid-tropical setting.
#    •  There are no large, angular or rectilinear earthworks, causeways, or ring-ditch patterns unmistakably visible at this sun angle and scale.  Most of what you see is the fingerprint of natural surface erosion.
#
#    Possible subtle anomalies (all very low-confidence without LiDAR or ground truth):
#    –  Around the exact middle of the scene you can just barely make out a faint, roughly circular outline (~40–60 m across) where the drainage thins out into a ring-like set of mini-ravines.  This could be a natural knoll with slightly harder caprock, or conceivably a very eroded ring-ditch or mound complex.
#    –  In one zone on the lower right quadrant there is a pair of parallel straight-ish lineaments about 10–20 m apart, each only a couple of gullies wide.  They trend NE–SW and could be old access paths or minor canals, but they are barely above noise level.
#
# 2.  Panel B (upper-right):
#    •  Appears entirely black (no data or no visible features).  Either the data were not acquired for this frame or it is a dead/dropped tile.  No geomorphic or archaeological information to extract here.
#
# 3.  Interpretation and next steps:
#    •  Geomorphology: what you’re seeing in Panel A is the signature of humid-tropical hill country eroded into branching V-shaped valleys with low narrow ridges.  There is no indication of large stable plateaus or mesa-type features.
#    •  Archaeology: there are no clear large geometric enclosures, ditched agricultural fields or causeways visible at this resolution and sun-lighting.  The very faint circular and linear hints noted above should be treated with extreme caution—they could be mapping artifacts, variations in lithology, or simply deeper natural gullies aligning by chance.
#    •  To pull any of these features out of the noise you would need:
#      –  Higher-resolution LiDAR with reliable ground returns under canopy.
#      –  Multispectral or thermal imaging to look for soil-moisture anomalies over suspected ditch/mound sites.
#      –  Field-check any candidate “ring” or straight-line segment to see if there is cultural fill, charcoal, terra preta, or stone alignments.
#
# In short, at the present scale and lighting, the terrain is overwhelmingly natural dendritic drainage.  There are no unambiguous anthropogenic earthworks in the grayshade panel, although faint circular or linear lineaments may warrant follow-up with LiDAR or targeted ground survey.
#
# Processing FN2_A01_2013_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for FN2_A01_2013_stitched:
# Below is a description of what the stripe of terrain shows, broken into (1) the broad geomorphology, (2) the drainage-network pattern, and (3) a careful look at spots that might conceal subtle archaeological features.
#
# 1.  Broad geomorphology
#    •  Dissected ridge–valley topography: the long, light‐gray “spine” running roughly north–south down the center of the strip is a low ridge or raised terrace.  On either side of it you see darker tonal bands that represent incised stream valleys.  The whole package looks like a small segment of an old plateau that has been cut into a series of parallel ridges with intervening hollows.
#    •  Valley floors and terraces: the darker, broader patches on the right-hand side toward mid-image form a fairly flat, wide valley floor – quite possibly a floodplain or an abandoned meander belt – whereas the left side is more rugged and steep, with convex spurs dropping toward the main valley.
#    •  Saddle and spur geometry: about halfway down you can make out a saddle‐shaped narrowing of the central ridge where two shorter spurs break off to the east and west.  Below that it opens into a wider flat zone, and at the very bottom the ridge pinches off again into a narrow gorge.
#
# 2.  Drainage network
#    •  Dendritic streams: nearly every dark line is a small drainage line, rill or ephemeral channel running into the main valley.  Many of these feeders display a classic dendritic (“tree‐like”) pattern, indicative of relatively uniform, non‐fractured bedrock or thick, homogenous soil cover.
#    •  Paleochannels: in the broad valley mid-image you can trace faint meanders – old channels now filled or abandoned – that curve through the light-gray floor.  Those sinuous loops suggest former river courses, perhaps cut off as the river migrated or as local sedimentation raised the floor.
#    •  Terraces and benches: stepped horizontal lines along the valley sides hint at cut-and-fill terraces, either natural (river‐scoured benches) or possibly remnant agricultural terraces (harder to prove at this scale).
#
# 3.  Possible archaeological anomalies
#    At first glance this looks overwhelmingly natural, but a few spots merit a second look:
#    •  Rectilinear plateau fragment (mid-low image, slightly to the right of center): a faint, almost straight-edged bench about 30–50 m long, aligned at roughly 30° to north, doesn’t quite follow the natural slope lines.  It could be the remnant of a raised pathway or old field boundary.
#    •  Oval depression (lower third, left half): a roughly 20 × 15 m ovoid hollow that interrupts the slope.  Natural slumping can create similar forms, but its relatively constant width and smooth outline raises the question of a small ditched enclosure or water‐management feature.
#    •  Linear scar (upper quarter, right side): a very shallow, nearly straight trough about 200 m long, cutting across contour lines at a constant grade.  It could be a former causeway or logging/track scar that follows an unnatural bearing.
#    •  Tiny mound‐and-ditch patterns: if you zoom in on the flattest portions of the floodplain segments, you can pick out a few dimples in a rough 40 × 40 m grid.  These are so slight they may just be differential compaction, but agricultural raised‐field systems elsewhere in Amazonia are known to leave patterns on the order of tens of meters.
#
# Next steps for verification
#    –  High‐resolution LiDAR under leaf-off conditions will help confirm whether these rectilinear and curvilinear shapes are natural artifacts of erosion or genuine anthropogenic earthworks.
#    –  Targeted ground survey and soil analysis (looking for terra preta, charcoal concentrations, postholes) could pick up where the DEM shading leaves off.
#    –  Aerial multispectral/satellite imagery in dry‐season windows sometimes makes buried ditches or buried foundations stand out as crop‐health anomalies.
#
# In sum, the dominant impression is of a classic Amazonian dissected‐plateau landscape, with a clear ridge-and-valley morphology and a tangle of modern and paleo‐drainage.  But at least three spots (the short straight bench, the ovoid hollow, and the faint linear cut) show just enough geometric ordering that they deserve on-the-ground follow-up as possible traces of pre-Columbian earthworks.
#
# Processing CON_A01_2015_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for CON_A01_2015_stitched:
# Below is a summary of what I see in the two images you provided.  I’ve broken the description into (1) natural terrain form and drainage patterns visible in the raw DEM (first image) and (2) the anomalous, likely anthropogenic shapes highlighted in the second (mask) image.
#
# 1.  Natural terrain / geomorphology (first image)
#    •  Regional slope and relief
#       –  The scene is moderately dissected, with relief on the order of tens of meters from ridge top to valley bottom.
#       –  Overall slopes appear gentle to moderate (roughly 5–15° on average), but locally steeper along the sharper ridges and entrenched ravines.
#
#    •  Drainage network
#       –  A classic dendritic pattern. Narrow, branching channels run downhill and coalesce into progressively larger tributaries.
#       –  Valley bottoms are narrow and V-shaped in cross section—typical of active incision in a humid tropical setting.
#       –  Several small colluvial fans or toe-slopes appear where first‐order channels emerge from steeper sidewalls.
#
#    •  Ridges and spurs
#       –  Convex‐up ridge crests topped by thin soil cover or shallow regolith.
#       –  Spurs that separate adjacent ravines are rounded at their crowns but sharpen markedly where erosion has undercut them.
#
#    •  Micro-terraces / benching
#       –  I can make out a few very subtle, linear benches on some of the lower‐slope hollows. These appear as faint, nearly level steps—possible shallow river-cut benches or colluvial terrace remnants.
#       –  If man-made, such terraces might have been leveled for planting or settlement, but they are so subtle here that they could also be natural strath terraces.
#
# 2.  Archaeological anomalies (second image; white = masked‐out terrain, black squares are the highlighted features)
#    The mask isolates five nearly perfect square “holes” or blocks that do not conform to natural drainage or slope forms. Their key characteristics:
#    •  Sharp 90° corners and straight edges, each forming a roughly square footprint.
#    •  Uniform size across most of them—indicating a single design standard or construction episode.
#    •  Concentration on slightly raised, gently sloping platforms above the main ravines (they avoid the steepest terrain).
#    •  Spacing that hints at a loose grid or cluster, rather than random scatter.
#
#    Such square‐planform anomalies in humid‐tropical DEMs are very likely to be small earthworks or settlement mounds, not natural. In this region of Amazonia around Brazil, they could correspond to:
#    – Raised agricultural “garden” platforms or small “camellones” (agricultural raised fields).
#    – The bases of wooden‐palisaded hamlets or defensive platforms.
#    – Granaries, storage pits, or ceremonial plazas with perfectly orthogonal embankments.
#
# 3.  Interpretation and recommendations
#    •  The overall landscape is one of classic tropical hill country, with active stream incision and frequent narrow ridges—the sort of ground where ancient communities often built raised platforms just upslope of seasonal streams.
#    •  The orthogonal, uniform‐sized features are almost certainly anthropogenic. They stand out sharply against the otherwise smoothly curving, dendritic terrain.
#    •  To verify:
#       – Overlay these coordinate positions on recent high‐resolution satellite or drone imagery to look for crop marks, soil discoloration, or vegetation changes.
#       – Conduct low‐impact field visits or ground‐penetrating radar along the edges of the identified squares.
#       – Compare with any known cadastral or archaeological site records in local surveys.
#
# In sum, the bulk of the scene is natural Amazonian hill‐and‐valley topography with a standard tropical drainage network, but the second image’s square anomalies almost certainly mark former earthworks or agricultural/settlement platforms worthy of targeted archaeological investigation.
#
# Processing CAN_A02_2014_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for CAN_A02_2014_stitched:
# Below is a brief geomorphological sketch of what your two grayscale panels are showing, followed by notes on any possible anthropic (archaeological) signatures. In both cases I have treated the images as low‐sun hillshades or simple height‐rasters (darker = lower, lighter = higher).
#
# 1) Left‐hand panel (relief / hillshade)
#    • Dendritic drainage network
#      – A central, relatively dark (low) trunk valley runs from roughly the centre of the image off toward the left-edge.
#      – Numerous smaller V-shaped tributaries join it, giving a classic dendritic (tree-like) pattern characteristic of uniform bedrock or deeply weathered soils.
#    • Interfluves and spurs
#      – Between the tributaries are narrow, triangular spurs sloping down toward the channel.
#      – The interfluves (ridges between valleys) appear gently rounded rather than sharp—suggesting mature erosion in a humid‐tropical setting.
#    • Local high point / knoll
#      – Toward the lower right quadrant you see a light (higher) dome with radial short gullies emanating from it—probably a small resistant outcrop or erosional remnant.
#    • Slope breaks and benches
#      – In places, notably along the north‐eastern edge of the main valley, there are subtle mid‐slope benches (slightly less steep breaks in gradient) that could mark harder soil horizons or pausing points in river downcutting.
#    • Interpretation
#      – Overall this is a natural fluvial‐erosion landscape on a relatively uniform substrate. There is no obvious linear embankment, rectilinear feature or perfect circle that would immediately scream “earthwork” or ancient road.
#
# 2) Right‐hand panel (near-uniform black)
#    • No topographic detail visible
#    • Either this is a masked-out area or a data void (missing LIDAR returns, dense canopy, or deliberately blanked background).
#    • No discernible relief, drainage or man-made geometry can be extracted.
#
# 3) Archaeological anomaly check
#    • No straight, evenly spaced ditches or embankments are visible in the left panel. Everything follows natural, dendritic curvature.
#    • No perfect circles, orthogonal corners, or linear avenues (all common tell-tales of Amazonian geoglyphs or earthworks) can be picked out.
#    • The benches and spur-edges are smoothly graded, consistent with soil‐horizon changes or lithologic layering, not human excavation.
#
# Conclusion
# – The first image displays a mature, fully forested (or formerly forested) hilly terrain incised by natural streams and gullies.
# – The second image contains no relief data.
# – No clear archaeological constructs (ditches, embankments, ringworks, causeways) appear in either panel. Ground‐truthing with higher-resolution LiDAR hillshades or subsurface probing would be needed to reveal any buried anthropic features.
#
# Processing CAG_A01_2013_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for CAG_A01_2013_stitched:
# Below is a summary of what I can see in the two images and why there do not appear to be any clear anthropogenic or archaeological “anomalies” showing up at this scale and in these renders.
#
# 1. Image 1 (grayscale)
#  • Overall character: very low‐relief, almost monolithic shading with a very gradual NW–SE tonal gradient. This is typical of deeply weathered “terra firme” in the central Amazon or of a smoothed digital elevation model (DEM) showing minimal microtopography.
#  • Slope/gradient: The slight brightening in the upper‐left quadrant suggests a very gentle rise or change in aspect there, but the change is on the order of centimeters to a few meters over the whole frame. No sharp escarpments, ridges or valley incisions are evident.
#  • Drainage: I see no discrete channel network, oxbow shapes, levees or paleochannels. The tonal field is too uniform. If there were an incised creek bed or abandoned river loop, it would appear as a thin darker line or a looped lighter tone, neither of which is present.
#  • Terraces/hummocks: No step‐like benches or regularly spaced hummocks that might indicate earthworks or pre-Columbian raised fields. The surface looks almost featureless except for the very gentle gradient.
#
# 2. Image 2 (black‐and-white)
#  • Character: this appears to be a binary mask or clipping of some kind rather than a raw photograph or DEM. The white “blobs” on the black background are full-frame, blocky, geometric polygons that bear no resemblance to natural drainage patterns, ridges or archaeological outlines.
#  • Interpretation: because the shapes are sharp-edged and unconnected (and in fact mirror neither stream networks nor circular ditches), they read as artifacts of image processing (for example, an over-aggressive threshold, or the mask of non-ground points in a LIDAR classification) rather than real landforms.
#
# Conclusion
# – Geomorphology: the site exhibits extremely subdued relief with no obvious dendritic drainage lines, terraces, levees or paleochannels.
# – Archaeological anomalies: there are no ring-ditches, rectilinear mounds, causeways or other earthworks visible. The only “features” in image 2 are processing artifacts.
# – Recommendation: if you are hunting for subtle anthropogenic features in Amazonian forest, you will need higher-resolution LiDAR (bare-earth DEM at sub-meter resolution) or targeted field survey, since at the scale presented here the terrain is simply too uniform and any man-made mounds or canals (often only 30 – 80 cm high) have been obscured by the smoothing inherent in these renders.
#
# Processing FN1_A01_2018_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for FN1_A01_2018_stitched:
# Below is a descriptive summary of what I see in each image, broken down into (1) major landform/vegetation‐cover patterns, and (2) anything that might hint at buried or lightly preserved human work.
#
# 1. Grayscale “hillshade”-type strip (Image 1)
#    • Overall character:
#      – A gently undulating surface of rounded, low‐relief ridges and swales typical of a forested Amazon floodplain or interfluvial plateau.
#      – No sharp peaks or deeply incised canyons – relief is on the order of tens of meters at most.
#
#    • Drainage and former channels:
#      – Dark, branching sinuous lineations near the top (north) likely mark active or relict stream trunks.
#      – Adjacent to them are faint scroll-bar patterns: crescentic ridges and small oxbow hollows that suggest abandoned meanders.
# ...
# - Ground-checking any subtle terrace-like bench (e.g. the bulge at bottom center of Image 2) might be warranted, but from the relief data alone, these look like natural colluvial benches or ridge spurs.
#
# Conclusion
# Both scenes display textbook dendritic drainage on low‐relief uplands—small V-shaped valleys and narrow spurs—without clear geometric or rectilinear anomalies. If you have field or multi-spectral data available, you could target the few bench-like spurs or subtle breaks in slope for soil sampling, but on the LiDAR/shaded‐relief alone there is no unambiguous sign of earthworks or settlements.
#
# Processing ANTL5800C8970_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for ANTL5800C8970_stitched:
# Here’s a breakdown of what both of these small DEM‐style hillshade chips are telling us, and why I don’t see any unmistakable ruins or earthworks lurking in them:
#
# 1. General terrain style
#    • Both images show classic dendritic (i.e. tree-like) drainage on low‐relief tropical hills, carved into easily eroded sediments.
#    • Ridges (light tones) and valleys or gullies (dark tones) are tightly interleaved, indicating relatively uniform bedrock or soil strength and no major structural control (faults or big resistant layers).
#    • There are no steep escarpments or cliff faces—slopes are gentle to moderate, consistent with the rolling topography of the Brazilian Amazon’s uplands rather than the steep Andean foreland.
#
# 2. Image #1 (upper left, ~200 m across)
#    • You see a network of very fine, closely spaced tributary gullies feeding into slightly larger, converging channels at the center and margins.
#    • The pattern is highly dendritic—no straight lines, right angles, or repeating motifs. That argues strongly in favor of purely natural erosion.
#    • Ridges are narrow and rounded; valley bottoms are narrow and v-shaped. Classic colluvial slopes in a humid-tropical rainfall regime.
#
# 3. Image #2 (lower right, ~400 m across)
#    • Scale-up of the same style of hills and valleys, but the channels are a little broader and more sinuous. You can even make out the gradual meander of what looks like a small, natural stream channel trending roughly north–south through the middle of the chip.
#    • At the confluence in the lower-center of the image you see three “feeder” valleys coming together—again, all with smoothly curving planforms.
#    • The flanks of the main channel have very gently sloping levee-like berms, but these are irregular in width and height. There are no straight, parallel berms or rectangular raised fields that you’d expect if these were anthropogenic canals or fish-pond features.
#
# 4. Looking for archaeological anomalies
#    • Earthworks in Amazonia (raised fields, causeways, enclosure ditches or geoglyphs) tend to show rectilinear or circular geometries, straight segments, uniform spacing, or distinct edge crests. None of those appear here.
#    • All the ridges and hollows follow random, branching patterns with variable spacing and curvature. That is almost a smoking gun that these are purely natural landforms.
#    • No isolated rectangular platforms, no ring-ditches, no straight causeways cutting across ridges—you would see a stark contrast to the dendritic network if there were.
#
# 5. Conclusion
#    Both scenes are textbook examples of natural fluvial-erosional topography in a low‐relief tropical landscape. While other sites elsewhere in Amazonia do host LIDAR‐revealed earthworks, these two do not show any anomalous straight lines or geometric features that would mark them out as archaeological. Everything visible here can be comfortably explained as small‐stream valleys incised into soft sediments, with the familiar dendritic branching that comes from overland flow in a humid tropical setting.
#
# Processing BAR_A01_2014_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for BAR_A01_2014_stitched:
# Below is a summary of what stands out in these two gray‐tone scenes.  I have first broken out the purely geomorphic (“natural”) elements and then pointed out the handful of features that might warrant a second look as possible anthropogenic or archaeological remnants.
#
# 1) IMAGE #1 (river and floodplain view)
#    Major geomorphological elements
#    • Meandering‐to‐braided alluvial channel (dark tones):
#      – Multiple active threads running roughly west–east at the top of the frame.
#      – At least two mid‐channel bars or emergent islands showing partial vegetation cover (gray‐mottled patches within the darkest river body).
#    • Oxbow and back‐swamp terrain on the distal floodplain (middle band of the image):
#      – Curving pale ridges (point bars) with faint crescent shapes pointing downstream.
#      – Abandoned channel scars and pond depressions (slightly darker “ghost” river loops).
#      – A transitional levee‐crest line running parallel to the main channel (a subtle high line separating the active river corridor from the outer floodplain).
#    • The outer floodplain and terrace (bottom half):
#      – A dendritic network of narrow tributary rills draining toward the main stem.
#      – Fine‐grained overbank deposits that exhibit a mottled texture, interspersed with very shallow swales.
#      – Several small, linear drainage “fingers” incising the terrace—typical of periodic sheet flooding and subsurface seepage.
#
#    Possible archaeological or anthropogenic anomalies
#    • A gently sinuous ridge running roughly NW–SE across the central floodplain (just below the levee line).  It does not perfectly align with natural point‐bar geometry, and it cuts across small tributaries at a slightly oblique angle.  While it could be a remnant of an old natural levee or paleo‐channel, it is worth checking on the ground or with higher‐resolution LiDAR to see if that ridge has a more regular cross section (for example an earthwork berm).
#    • Faint, short, straight‐ish segments of slight elevation change along that same ridge—too small to map as full geoglyphs, but they might be the corners of former field boundaries or low earthen enclosures if they turn out to join up in a larger pattern.
#
# 2) IMAGE #2 (mosaic‐style elevation panels)
#    Major geomorphological elements
#    • Overall very low‐relief plain, with smooth, rolling microtopography.
#    • Slight convex “knolls” and shallow depressions spread irregularly—indicative of subtle pediplanation over ancient floodplain sands or low‐energy colluvium.
#    • A handful of dendritic, branching depressions (narrow and shallow) that look like inter‐knoll drainage—consistent with seasonal sheet flow rather than a clearly incised channel.
#
#    Possible archaeological or anthropogenic anomalies
#    • I do not see any large, regular polygons, right‐angled features, or radial symmetry that one would associate with Amazonian earthwork geoglyphs or pre‐Columbian ditch‐and‐bank systems.
#    • The mosaic’s black gaps and odd panel edges are data‐coverage artifacts rather than real ground shapes; most of the very straight edges and rectangular cutouts are simply where no elevation data exist.
#    • If anything, one might flag a few slightly sharper‐curved hollow lines along panel boundaries, but these all coincide with tile seams.  Absent a continuous line or discernible pattern, there is no strong evidence here of buried walls, raised fields, or ditched enclosures.
#
# —
# Conclusion: The first image is dominated by active meander‐belt processes (braided/meandering channels, point bars, oxbow scars), with one faint sinuous ridge that could merit closer remote‐sensing or field checking for possible earthwork origin.  The second image appears to be a low‐relief digital‐elevation mosaic over natural alluvial or colluvial terrain; no clear anthropogenic geometries jump out once you discount the tile boundaries.
#
# Processing ANTL5770C8971_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for ANTL5770C8971_stitched:
# Both of these upland‐Amazon images are, at first glance, dominated by natural, dendritic drainage and low‐amplitude relief.  I have not been able to pick out any unmistakably artificial shapes—no obvious circles, rectangles, straight-line ditches or mounded platforms—though I do note a few subtle geomorphic details worth pointing out and tentatively relating to human use of the landscape.
#
# Image 1 (upper left):
# • Relief pattern: A classic dendritic “tree‐and‐branch” network of very small, tightly spaced V-shaped gullies feeding into slightly larger side‐valleys.
# • Interfluves (ridge crests) are smooth and convex in plan, with regular spacing of roughly 50–100 m between adjacent valley axes.
# • Overall slope appears gentle (likely on the order of 5° to 10°), so these gullies are probably ephemeral, cutting into lateritic soils or saprolite.
# • No straight or orthogonal alignments—everything fans out in a natural, fractal way.
#
# Image 2 (upper right):
# • Larger‐scale version of the same dendritic network. Branches here coalesce into a few main valleys that run generally NW→SE (top of image toward bottom).
# • Mid-image, a sinuous, relatively narrow dark band (just above center) cuts almost horizontally across the scene. It contrasts in tone with its surroundings, suggesting either:
#   – A lightly incised paleo-channel now filled with finer sediment and holding moisture, or
#   – A slightly lower terrace or linear peat pocket that drains differently than the adjoining slopes.
#   Either way, that feature could mark an old river course—places where indigenous settlements often clustered.
# • No well‐defined circular or geometric earthworks can be made out at this scale. The valleys remain natural in curvature, and the ridges show no straight edges or corners.
# • Lower right quadrant shows somewhat darker tonal “pools” or concavities but again these lack rectilinear boundaries—more likely local hollows or very shallow depressions collecting runoff.
#
# Archaeological “anomaly” candidates:
# 1. The sinuous band in Image 2 – it deserves a closer, higher-resolution look. If it is a buried channel or levee, it may correspond to a zone of higher soil fertility (“terra preta” zones often lie along old oxbows) or to the remnants of human canalization.
# 2. Slight tonal breaks along some ridge-crest shoulders. Although these follow the natural contour, they might—on very close inspection—reveal the edge of an old raised-field platform or the ditch‐and‐bank profile of a small earthwork.
#
# Conclusions:
# • Overall, both scenes are entirely consistent with natural, highly dissected lateritic uplands in the southern Amazon basin.
# • No unambiguous geoglyphs, enclosures or orthogonal causeways appear.
# • The one feature I’d flag for targeted follow-up is that horizontal, paleochannel-like trace in the middle of the second image—it may mark an area of past fluvial stability where pre-Columbian communities concentrated their earth‐working.
#
# A ground-truthing campaign or higher-resolution LIDAR derivatives (slope/aspect/color‐shaded relief) would be the next step to confirm whether any of these drainages and minor breaks in slope hide low mounds, ditches or raised agriculture platforms.
#
# Processing BON_A01_2013_stitched...
# Saved raster tile to /home/ziggy/dev/oaiarch/tile.tif
# → Contacting OpenAI …
# Analysis for BON_A01_2013_stitched:
# Below is a consolidated description of what I see in the two panels you supplied.  I will begin with the raw‐looking grey‐scale image (which appears to be either LiDAR‐derived ground elevations or a very shallow radar‐derived DEM of a cleared forest surface), then discuss the overlaid mask (the high‐contrast black‐and‐white second panel) and finally call out the spots that I think merit closer archaeological follow-up.
#
# 1. Grey-scale image (ground model)
#    • Overall topography: very low‐relief, gently rolling terrain.  Elevation contrasts from crest to trough appear to be on the order of 1–3 m at most.
#    • Natural fluvial imprint: you can make out a faint dendritic network of old, abandoned channels or inter-dune swales.  These show up as slightly darker (lower) curving lines that branch and coalesce like a miniature, buried creek system.
#    • Subtle linear ridges: cutting across that network are sets of nearly parallel, elongated ridges, each ridge some 2–5 m wide, spaced roughly 8–12 m apart, and rising perhaps 0.5–1 m above the intervening swales.  In several places they bend in gentle “S-curves,” in others they form straight runs more than 50 m long before curving.
#    • Small oval mounds: superimposed on the ridges in places are small oval or lens-shaped bumps (diameters ~10–15 m), which stand out as little mounds rather than linear crests.
#    • No obvious modern roads or trails—everything here looks buried or long-abandoned.
#
# 2. Black-and-white mask (overhead depiction of “anomalies”)
#    • The white areas correspond almost exactly to the linear ridges and oval mounds in the grey data.  In other words, somebody has pre-segmented out the anthropogenic-looking forms.
#    • The shapes in white are highly geometric: straight-edged polygons, long triangles tapering to acute points, and remarkably regular, roughly trapezoidal patches.  They do not correspond to the natural drainage echoes (which remain masked in black).
#    • A few of the larger white polygons (up to 100 × 80 m in footprint) have very sharp corners—something one would not expect on a purely erosional or depositional feature.
#
# 3. Archaeological implications and anomalies
#    • Raised-field agriculture (camellones): The parallel ridges and intervening troughs are classic signatures of pre-Columbian raised-field farming systems reported elsewhere in seasonally flooded parts of the Amazon basin.  They elevated crops above seasonal inundation and improved drainage.
#    • Ditched or walled enclosures: The larger, sharply cornered white shapes look far too regular to be random natural levees.  They may be the buried remains of square or trapezoidal compounds, defensive earthworks or ceremonial plazas.
#    • Mound-and-plaza complexes: The oval mounds sitting atop or adjacent to the ridges (visible in the grey-scale) are the kinds of elevated platforms on which villages or ceremonial buildings would have been constructed.  Their consistent size (10–15 m diameter) and how they punctuate the ridge network is very suggestive of organized habitation.
#    • Subtle alignment patterns: At least one set of ridges trends almost exactly east–west; another set trends north–south.  Where they cross, they form near-perfect right‐angle intersections.  That orthogonality is a heavy clue to deliberate planning.
#
# 4. Recommendations for follow-up
#    • Ground truth key anomalies: Especially the large trapezoidal “white mask” shapes in the NE and SW quadrants.  A small auger or shovel test at their corners should reveal whether a ditch or embankment survives under the soil.
#    • Soil profiling on the parallel ridges vs. troughs: Look for contrasting fill (dark earth, charcoal flecks) in the ridge cores vs. natural alluvial deposits in the swales.  A classic Amazonian “terra preta” signature would clinch the raised-field hypothesis.
#    • Magnetometry/GPR over the regular mounds: To see whether there are buried postholes or paving stones within those oval platforms.
#
# In sum, this part of the basin shows very low relief but unmistakable signs of ancient earth-moving: long, evenly spaced raised-field ridges, discrete mounds, and at least two large rectilinear enclosures.  All of these fit the profile of a pre-Hispanic agricultural‐and-village landscape, and they’re well worth an on-the-ground reconnaissance and targeted subsurface testing.

# %% [markdown]
# ## Send tif Data to OpenAI

# %%
from typing import Tuple
import base64
from openai import OpenAI
import os

def raster_to_png_data_url(
    tif_path: Path, size: Tuple[int, int] = (512, 512)
) -> str:
    """
    Down-sample the first band of the GeoTIFF, scale to 8-bit, and
    return a data-URL (PNG, base-64) suitable for the OpenAI vision API.
    """
    with rasterio.open(tif_path) as src:
        data = src.read(1, masked=True).astype(np.float32)

    # Simple min-max stretch → 0-255
    z_min, z_max = np.nanmin(data), np.nanmax(data)
    arr = np.clip((data - z_min) / (z_max - z_min + 1e-9) * 255, 0, 255).astype(
        np.uint8
    )

    # Resize to something manageable for the API
    fig = plt.figure(frameon=False)
    fig.set_size_inches(*[s / 100 for s in size])
    ax = plt.Axes(fig, [0.0, 0.0, 1.0, 1.0])
    ax.set_axis_off()
    fig.add_axes(ax)
    ax.imshow(arr, cmap="gray", origin="upper")
    buf = io.BytesIO()
    fig.savefig(buf, format="png", dpi=100)
    plt.close(fig)

    png_base64 = base64.b64encode(buf.getvalue()).decode("ascii")
    return f"data:image/png;base64,{png_base64}"

def png_to_data_url(png_path: Path)-> str:
    """
    Convert a PNG file to a data-URL (base-64) suitable for the OpenAI vision API.
    """
    with open(png_path, "rb") as f:
        png_base64 = base64.b64encode(f.read()).decode("ascii")
    return f"data:image/png;base64,{png_base64}" 

def analyse_with_openai(
    image_data_urls: list[str],
    prompt: str = "Describe the major terrain / geomorphological features visible in these images in detail and look carefully for any archeologically interesting anomalies present.",
    model: str = "o4-mini",
    max_tokens: int = 400,
) -> str:
    """
    Send an image + prompt to GPT-4o’s vision endpoint and return the text.
    """
    client = OpenAI()  # picks up OPENAI_API_KEY from env
    print("→ Contacting OpenAI …")
    completion = client.chat.completions.create(
        model=model,
        messages=[
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": prompt},
                    *[{"type": "image_url", "image_url": {"url": url, "detail": "high"}} for url in image_data_urls],
                ],
            }
        ],
        # max_tokens=max_tokens,
    )
    return completion.choices[0].message.content.strip()

data_url_1 = raster_to_png_data_url(out_path_1)
data_url_2 = png_to_data_url('stitched_images/ANTL5770C8970_stitched.png')

analysis = analyse_with_openai([data_url_1, data_url_2])
# Out:
# → Contacting OpenAI …

# %%
print(analysis)
# Out:
# Below is a summary of what the two greyscale “hillshade-style” views reveal about the terrain, followed by a note on any possible archaeological anomalies.  Keep in mind that without higher-resolution data or ground-truthing, it is very difficult to pick out subtle anthropogenic features in a purely natural drainage network.
#
# 1.  Image 1 (small, highly detailed patch of terrain)
#     •  Dendritic micro-drainage
#        –  Very fine, fractal-like network of ephemeral rills and gullies
#        –  Small tributaries branching into ever-smaller side channels
#        –  Pattern is consistent with a relatively homogenous, easily eroded substrate (e.g. soft sedimentary rock, unconsolidated alluvium).
#     •  Interfluves and ridges
#        –  The lighter-toned, more even areas between channels represent low‐angle ridges or interfluves
#        –  Those interfluves slope gradually toward the nearest channel head, suggesting broad convex hilltops eroded into a gentle hillside.
#     •  Channel heads and colluvial fans
#        –  At the upper-left of the frame you can see a slightly larger, more entrenched channel from which many smaller tributaries radiate
#        –  Down-slope of that feature the finer fans of debris or colluvial fill form very shallow aprons along the valley sides.
#
# 2.  Image 2 (larger, lower-resolution hillshade)
#     •  Incised valley network on rolling terrain
#        –  A main trunk channel snakes through the center, with smaller tributaries tunneling in from the north and south
#        –  Valley bottoms appear relatively narrow; side slopes are moderate, judging by the gradation in shading
#     •  Spurs and headward erosion
#        –  On the right half of the image you can see the characteristic V-shaped hollows of headward-eroding streams protruding into upland ridges
#        –  Spurs are fairly regular, indicating the absence of major structural controls or fault-line valleys.
#     •  Possible alluvial benches or terraces
#        –  In the lower left quadrant there is a broad, relatively flat light-toned surface that could be an abandoned floodplain bench or old terrace
#        –  Above it, a subtle linear break in slope suggests a terrace riser at slightly higher elevation.
#
# 3.  Archaeological-interest anomalies?
#     •  No obvious rectilinear, circular or highly regular pattern (e.g. fortification earthworks, field-boundary walls, burial mounds) stands out in either image.
#     •  No straight, unnaturally oriented lines or right-angle corners that would point to walls, roads or enclosures.
#     •  The apparent “linear” features are almost all south- and north-facing slopes picked out by the hillshade, not human-made.
#     •  The only bench-like surface (possible terrace) could merit local field inspection—ancient peoples sometimes chose abandoned terraces for settlement or agriculture—but the geomorphology also explains it in purely natural terms.
#
# Conclusion: both images show a classic dendritic drainage landscape of moderate relief, with no unmistakable archaeological features visible at this scale. Any potential anomaly (for example, a faint terrace bench) would require higher-resolution imagery or on-the-ground survey to determine whether it conceals anthropogenic remains.

# %% [markdown]
# ## Display LiDAR data

# %%
import laspy
import numpy as np
import plotly.graph_objects as go
path_prefix = '/mnt/datasets/lidar_nasa/orders/926ea6cc8cdee77c3ed86112e89c08f5/LiDAR_Forest_Inventory_Brazil/data'

# Load the LAZ file
las = laspy.read(path_prefix + "/CAG_A01_2013_laz_4.laz")

# Extract coordinates
x = las.x
y = las.y
z = las.z

# Optional: downsample for performance
sample_indices = np.random.choice(len(x), size=min(100000, len(x)), replace=False)
x = x[sample_indices]
y = y[sample_indices]
z = z[sample_indices]

# Optional: use color if available
if hasattr(las, 'red') and hasattr(las, 'green') and hasattr(las, 'blue'):
    r = las.red[sample_indices] / 65535.0
    g = las.green[sample_indices] / 65535.0
    b = las.blue[sample_indices] / 65535.0
    colors = ['rgb({},{},{})'.format(int(r[i]*255), int(g[i]*255), int(b[i]*255)) for i in range(len(r))]
else:
    colors = z  # Color by height

# Create Plotly 3D scatter plot
fig = go.Figure(data=[
    go.Scatter3d(
        x=x, y=y, z=z,
        mode='markers',
        marker=dict(
            size=1.5,
            color=colors,  # Either RGB or scalar z values
            colorscale='Viridis' if isinstance(colors[0], (float, np.float64)) else None,
            opacity=0.8
        )
    )
])

fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
    ),
    title="LAZ Point Cloud",
    margin=dict(l=0, r=0, b=0, t=30)
)

fig.show()

# %% [markdown]
# ## Explore Brazil LiDAR Data

# %%
import pandas as pd

rects_df1 = pd.read_csv(path_prefix+'/cms_brazil_lidar_tile_inventory.csv')

# %%
locations = pd.read_csv('locations.csv')

def is_in_rect (min_lat, min_lon, max_lat, max_lon, lat, lon):
    return min_lat <= lat <= max_lat and min_lon <= lon <= max_lon

def measure(lat1, lon1, lat2, lon2):
    R = 6378.137  # Radius of earth in KM
    dLat = lat2 * np.pi / 180 - lat1 * np.pi / 180
    dLon = lon2 * np.pi / 180 - lon1 * np.pi / 180
    a = np.sin(dLat/2) * np.sin(dLat/2) + np.cos(lat1 * np.pi / 180) * np.cos(lat2 * np.pi / 180) * np.sin(dLon/2) * np.sin(dLon/2)
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    d = R * c
    return d * 1000  # meters

max_lat = rects_df1['max_lat'].max()
min_lat = rects_df1['min_lat'].min()
max_lon = rects_df1['max_lon'].max()
min_lon = rects_df1['min_lon'].min()

for i, row in locations.iterrows():
    x = row["x (UTM 19S)"]
    y = row["y (UTM 19S)"]
    lon, lat = convert_utm_to_wgs84(x, y)
    # if is_in_rect(min_lat, min_lon, max_lat, max_lon, lat, lon):
    #     print(f"Location {i} ({lon}, {lat}) is in the area of interest.")
    min_dist = 100000
    if(sum(df.apply(lambda row: is_in_rect(
        row['min_lat'], row['min_lon'], row['max_lat'], row['max_lon'],
        lat, lon
    ), axis=1).astype(int))) > 0:
        print(f"Location {i} ({lon}, {lat}) is in the area of interest.")
    else:
        # print(f"Location {i} ({lon}, {lat}) is NOT in the area of interest.")
        for j, row in rects_df1.iterrows():
            dist = measure(lat, lon, ((row['min_lat'] + row['max_lat']) / 2), ((row['min_lon'] + row['max_lon']) / 2))
            if dist < min_dist:
                min_dist = dist
        print(f"Closest tile has distance {min_dist}")
# Out:
# Closest tile has distance 22493.01561279689
# Closest tile has distance 12746.82596529049
# Closest tile has distance 6091.418838540096
# Closest tile has distance 30284.044860974773
# Closest tile has distance 29809.889965666614
# Closest tile has distance 14599.362185076781
# Closest tile has distance 14094.175551027642
# Closest tile has distance 23159.714085289197
# Closest tile has distance 22147.672245386206
# Closest tile has distance 11754.866020264179
# Closest tile has distance 22127.39810225144
# Closest tile has distance 10542.456070155553
# Closest tile has distance 20622.666556417753
# Closest tile has distance 46206.51286917486
# Closest tile has distance 46442.92362458514
# Closest tile has distance 46597.40759972237
# Closest tile has distance 21633.685727423977
# Closest tile has distance 18017.241561778836
# Closest tile has distance 10222.82367128146
# Closest tile has distance 38343.365775028695
# Closest tile has distance 29553.96984571322
# Closest tile has distance 50744.46263413651
# Closest tile has distance 42804.65841288116
# Closest tile has distance 23527.376190229632
# Closest tile has distance 45701.918461967834
# Closest tile has distance 39149.62073230412
# Closest tile has distance 28818.257298839675
# Closest tile has distance 10473.128014407479
# Closest tile has distance 3775.997347408506
# Closest tile has distance 21807.60336996887
# Closest tile has distance 12950.381475261353
# Closest tile has distance 13897.38836444823
# Closest tile has distance 100000
# Closest tile has distance 13090.754265347647
# Closest tile has distance 19082.148451611236
# Closest tile has distance 18064.393324678535
# Closest tile has distance 13903.423996301244
# Closest tile has distance 39238.61286708667

# %%
rects_df2 = pd.read_csv('cms_brazil_lidar_2.csv')
rects_df2.columns
# Out:
# Index(['SURVEY', 'FILENAME', 'SOFTWARE', 'NUM_PTS', 'NUM_RET1', 'NUM_RET2',
#        'NUM_RET3', 'NUM_RET4', 'NUM_RET5', 'X_SF', 'Y_SF', 'Z_SF', 'X_MIN',
#        'Y_MIN', 'X_MAX', 'Y_MAX', 'Z_MIN', 'Z_MAX', 'LONG_MIN', 'LAT_MIN',
#        'LONG_MAX', 'LAT_MAX', 'COMPRESSION', 'INTENSITY_MIN', 'INTENSITY_MAX',
#        'NUM_RET_MIN', 'NUM_RET_MAX', 'NUM_GROUND', 'NUM_LOWVEG', 'NUM_MEDVEG',
#        'NUM_HIVEG'],
#       dtype='object')

# %%
for i, row in locations.iterrows():
    x = row["x (UTM 19S)"]
    y = row["y (UTM 19S)"]
    lon, lat = convert_utm_to_wgs84(x, y)
    min_dist = 10000000
    if(sum(rects_df2.apply(lambda row: is_in_rect(
        row['LAT_MIN'], row['LONG_MIN'], row['LAT_MAX'], row['LONG_MAX'],
        lat, lon
    ), axis=1).astype(int))) > 0:
        print(f"Location {i} ({lon}, {lat}) is in the area of interest.")
    else:
        # print(f"Location {i} ({lon}, {lat}) is NOT in the area of interest.")
        for j, row in rects_df2.iterrows():
            dist = measure(lat, lon, ((row['LAT_MIN'] + row['LAT_MAX']) / 2), ((row['LONG_MIN'] + row['LONG_MAX']) / 2))
            if dist < min_dist:
                min_dist = dist
        print(f"Closest tile has distance {min_dist}")
# Out:
# Closest tile has distance 2163186.646734469
# Closest tile has distance 2170894.205302072
# Closest tile has distance 2192271.3252928704
# Closest tile has distance 2234433.992477616
# Closest tile has distance 2233827.0785714863
# Closest tile has distance 2171389.7477313876
# Closest tile has distance 2171922.5291825314
# Closest tile has distance 2227051.426037658
# Closest tile has distance 2226560.054747479
# Closest tile has distance 2171442.758256579
# Closest tile has distance 2204387.459030878
# Closest tile has distance 2174259.579588374
# Closest tile has distance 2194779.160724361
# Closest tile has distance 2243158.7344731716
# Closest tile has distance 2243065.5771416845
# Closest tile has distance 2242067.7303717076
# Closest tile has distance 2224473.3677285
# Closest tile has distance 2220180.122377464
# Closest tile has distance 2196170.5413814974
# Closest tile has distance 2206613.339182513
# Closest tile has distance 2183063.218579512
# Closest tile has distance 2215093.7129463567
# Closest tile has distance 2228723.8754438395
# Closest tile has distance 2293655.7372663715
# Closest tile has distance 2242694.164928714
# Closest tile has distance 2228338.3522316874
# Closest tile has distance 2222503.561672945
# Closest tile has distance 2210803.163614901
# Closest tile has distance 2182889.9226890905
# Closest tile has distance 2163743.7134048394
# Closest tile has distance 2173899.5236859224
# Closest tile has distance 2199694.428654352
# Closest tile has distance 2453850.911227566
# Closest tile has distance 2198823.100254873
# Closest tile has distance 2193177.130443578
# Closest tile has distance 2201801.7271159263
# Closest tile has distance 2213526.8231571885
# Closest tile has distance 2242622.431142658

# %%
pd.set_option('display.max_colwidth', None)
print(df.iloc[0].to_string())
# Out:
# filename                                                                  ANA_A01_2017_laz_0.laz
# max_lat                                                                                -3.363488
# min_lat                                                                                -3.372548
# max_lon                                                                               -54.992912
# min_lon                                                                               -55.001927
# file_type                                                                             pointcloud
# file_size_mb                                                                           85.374953
# file_format                                                                              LAS/LAZ
# version                                                                                      1.2
# created                                                                                 214/2017
# utmzone                                                                                      21S
# srs             +proj=utm +zone=21 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=m +no_defs

# %%
list(filter(lambda f: f.endswith('.csv'), os.listdir(path_prefix)))
# Out:
# ['cms_brazil_lidar_tile_inventory.csv']

# %%
len(df)
# Out:
# 3152

# %%
len(os.listdir(path_prefix))
# Out:
# 3154

# %%
from zipfile import ZipFile
from fastkml import kml


kmz_path = path_prefix+'/cms_brazil_lidar_tile_inventory.kmz'

# Step 1: List contents
with ZipFile(kmz_path, 'r') as kmz:
    print("Files in KMZ:")
    for name in kmz.namelist():
        print(name)

correct_kml_path = 'cms_brazil_lidar_tile_inventory.kml'  # Replace with actual name printed above
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 from zipfile import ZipFile
#       2 from fastkml import kml
# ----> 5 kmz_path = path_prefix+'/cms_brazil_lidar_tile_inventory.kmz'
#       7 # Step 1: List contents
#       8 with ZipFile(kmz_path, 'r') as kmz:
#
# NameError: name 'path_prefix' is not defined
